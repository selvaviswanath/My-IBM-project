# %% [markdown]
# ### Libraries and Dataset

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pnd
import numpy as NP
data = pnd.read_csv(r"dataset.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10998 entries, 0 to 10997
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   index                        10998 non-null  int64
#  1   having_IPhaving_IP_Address   10998 non-null  int64
#  2   URLURL_Length                10998 non-null  int64
#  3   Shortining_Service           10998 non-null  int64
#  4   having_At_Symbol             10998 non-null  int64
#  5   double_slash_redirecting     10998 non-null  int64
#  6   Prefix_Suffix                10998 non-null  int64
#  7   having_Sub_Domain            10998 non-null  int64
#  8   SSLfinal_State               10998 non-null  int64
#  9   Domain_registeration_length  10998 non-null  int64
#  10  Favicon                      10998 non-null  int64
#  11  port                         10998 non-null  int64
#  12  HTTPS_token                  10998 non-null  int64
#  13  Request_URL                  10998 non-null  int64
#  14  URL_of_Anchor                10998 non-null  int64
#  15  Links_in_tags                10998 non-null  int64
#  16  SFH                          10998 non-null  int64
#  17  Submitting_to_email          10998 non-null  int64
#  18  Abnormal_URL                 10998 non-null  int64
#  19  Redirect                     10998 non-null  int64
#  20  on_mouseover                 10998 non-null  int64
#  21  RightClick                   10998 non-null  int64
#  22  popUpWidnow                  10998 non-null  int64
#  23  Iframe                       10998 non-null  int64
#  24  age_of_domain                10998 non-null  int64
#  25  DNSRecord                    10998 non-null  int64
#  26  web_traffic                  10998 non-null  int64
#  27  Page_Rank                    10998 non-null  int64
#  28  Google_Index                 10998 non-null  int64
#  29  Links_pointing_to_page       10998 non-null  int64
#  30  Statistical_report           10998 non-null  int64
#  31  Result                       10998 non-null  int64
# dtypes: int64(32)
# memory usage: 2.7 MB

# %%
data.isnull().any()
# Out:
# index                          False
# having_IPhaving_IP_Address     False
# URLURL_Length                  False
# Shortining_Service             False
# having_At_Symbol               False
# double_slash_redirecting       False
# Prefix_Suffix                  False
# having_Sub_Domain              False
# SSLfinal_State                 False
# Domain_registeration_length    False
# Favicon                        False
# port                           False
# HTTPS_token                    False
# Request_URL                    False
# URL_of_Anchor                  False
# Links_in_tags                  False
# SFH                            False
# Submitting_to_email            False
# Abnormal_URL                   False
# Redirect                       False
# on_mouseover                   False
# RightClick                     False
# popUpWidnow                    False
# Iframe                         False
# age_of_domain                  False
# DNSRecord                      False
# web_traffic                    False
# Page_Rank                      False
# Google_Index                   False
# Links_pointing_to_page         False
# Statistical_report             False
# Result                         False
# dtype: bool

# %%
data.describe()
# Out:
#               index  having_IPhaving_IP_Address  URLURL_Length  \
# count  10998.000000                10998.000000   10998.000000
# mean    5499.500000                    0.316239      -0.632570
# std     3174.993465                    0.948723       0.766573
# min        1.000000                   -1.000000      -1.000000
# 25%     2750.250000                   -1.000000      -1.000000
# 50%     5499.500000                    1.000000      -1.000000
# 75%     8248.750000                    1.000000      -1.000000
# max    10998.000000                    1.000000       1.000000
#
#        Shortining_Service  having_At_Symbol  double_slash_redirecting  \
# count        10998.000000      10998.000000              10998.000000
# mean             0.737952          0.700855                  0.741226
# std              0.674883          0.713336                  0.671286
# min             -1.000000         -1.000000                 -1.000000
# 25%              1.000000          1.000000                  1.000000
# 50%              1.000000          1.000000                  1.000000
# 75%              1.000000          1.000000                  1.000000
# max              1.000000          1.000000                  1.000000
#
#        Prefix_Suffix  having_Sub_Domain  SSLfinal_State  \
# count   10998.000000       10998.000000    10998.000000
# mean       -0.734679           0.062830        0.252046
# std         0.678446           0.816956        0.911633
# min        -1.000000          -1.000000       -1.000000
# 25%        -1.000000          -1.000000       -1.000000
# 50%        -1.000000           0.000000        1.000000
# 75%        -1.000000           1.000000        1.000000
# max         1.000000           1.000000        1.000000
#
#        Domain_registeration_length  ...   popUpWidnow        Iframe  \
# count                 10998.000000  ...  10998.000000  10998.000000
# mean                     -0.336970  ...      0.614112      0.817421
# std                       0.941558  ...      0.789255      0.576066
# min                      -1.000000  ...     -1.000000     -1.000000
# 25%                      -1.000000  ...      1.000000      1.000000
# 50%                      -1.000000  ...      1.000000      1.000000
# 75%                       1.000000  ...      1.000000      1.000000
# max                       1.000000  ...      1.000000      1.000000
#
#        age_of_domain     DNSRecord   web_traffic     Page_Rank  Google_Index  \
# count   10998.000000  10998.000000  10998.000000  10998.000000  10998.000000
# mean        0.057829      0.374432      0.286325     -0.482270      0.721586
# std         0.998372      0.927297      0.828549      0.876063      0.692357
# min        -1.000000     -1.000000     -1.000000     -1.000000     -1.000000
# 25%        -1.000000     -1.000000      0.000000     -1.000000      1.000000
# 50%         1.000000      1.000000      1.000000     -1.000000      1.000000
# 75%         1.000000      1.000000      1.000000      1.000000      1.000000
# max         1.000000      1.000000      1.000000      1.000000      1.000000
#
#        Links_pointing_to_page  Statistical_report        Result
# count            10998.000000        10998.000000  10998.000000
# mean                 0.343972            0.718312      0.114384
# std                  0.570066            0.695752      0.993482
# min                 -1.000000           -1.000000     -1.000000
# 25%                  0.000000            1.000000     -1.000000
# 50%                  0.000000            1.000000      1.000000
# 75%                  1.000000            1.000000      1.000000
# max                  1.000000            1.000000      1.000000
#
# [8 rows x 32 columns]

# %%
corr=data.corr()
fig,ax=plt.subplots(figsize=(10,10))
ax.legend()
cax=ax.matshow(corr)
fig.colorbar(cax)
plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical')
plt.yticks(range(len(corr.columns)), corr.columns)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ([<matplotlib.axis.YTick at 0x7ff6855de760>,
#   <matplotlib.axis.YTick at 0x7ff6855dedc0>,
#   <matplotlib.axis.YTick at 0x7ff6858f2af0>,
#   <matplotlib.axis.YTick at 0x7ff6856563a0>,
#   <matplotlib.axis.YTick at 0x7ff685656af0>,
#   <matplotlib.axis.YTick at 0x7ff685659280>,
#   <matplotlib.axis.YTick at 0x7ff6856599d0>,
#   <matplotlib.axis.YTick at 0x7ff685659520>,
#   <matplotlib.axis.YTick at 0x7ff685656370>,
#   <matplotlib.axis.YTick at 0x7ff685661040>,
#   <matplotlib.axis.YTick at 0x7ff685661670>,
#   <matplotlib.axis.YTick at 0x7ff685661dc0>,
#   <matplotlib.axis.YTick at 0x7ff685668550>,
#   <matplotlib.axis.YTick at 0x7ff685668ca0>,
#   <matplotlib.axis.YTick at 0x7ff685668640>,
#   <matplotlib.axis.YTick at 0x7ff6856497f0>,
#   <matplotlib.axis.YTick at 0x7ff68566d160>,
#   <matplotlib.axis.YTick at 0x7ff68566d820>,
#   <matplotlib.axis.YTick at 0x7ff685674040>,
#   <matplotlib.axis.YTick at 0x7ff685674700>,
#   <matplotlib.axis.YTick at 0x7ff68566dfd0>,
#   <matplotlib.axis.YTick at 0x7ff685656670>,
#   <matplotlib.axis.YTick at 0x7ff685674970>,
#   <matplotlib.axis.YTick at 0x7ff684e8c3a0>,
#   <matplotlib.axis.YTick at 0x7ff684e8caf0>,
#   <matplotlib.axis.YTick at 0x7ff684e91280>,
#   <matplotlib.axis.YTick at 0x7ff684e919d0>,
#   <matplotlib.axis.YTick at 0x7ff684e8cbe0>,
#   <matplotlib.axis.YTick at 0x7ff685656a60>,
#   <matplotlib.axis.YTick at 0x7ff684e99040>,
#   <matplotlib.axis.YTick at 0x7ff684e99670>,
#   <matplotlib.axis.YTick at 0x7ff684e99dc0>],
#  [Text(0, 0, 'index'),
#   Text(0, 1, 'having_IPhaving_IP_Address'),
#   Text(0, 2, 'URLURL_Length'),
#   Text(0, 3, 'Shortining_Service'),
#   Text(0, 4, 'having_At_Symbol'),
#   Text(0, 5, 'double_slash_redirecting'),
#   Text(0, 6, 'Prefix_Suffix'),
#   Text(0, 7, 'having_Sub_Domain'),
#   Text(0, 8, 'SSLfinal_State'),
#   Text(0, 9, 'Domain_registeration_length'),
#   Text(0, 10, 'Favicon'),
#   Text(0, 11, 'port'),
#   Text(0, 12, 'HTTPS_token'),
#   Text(0, 13, 'Request_URL'),
#   Text(0, 14, 'URL_of_Anchor'),
#   Text(0, 15, 'Links_in_tags'),
#   Text(0, 16, 'SFH'),
#   Text(0, 17, 'Submitting_to_email'),
#   Text(0, 18, 'Abnormal_URL'),
#   Text(0, 19, 'Redirect'),
#   Text(0, 20, 'on_mouseover'),
#   Text(0, 21, 'RightClick'),
#   Text(0, 22, 'popUpWidnow'),
#   Text(0, 23, 'Iframe'),
#   Text(0, 24, 'age_of_domain'),
#   Text(0, 25, 'DNSRecord'),
#   Text(0, 26, 'web_traffic'),
#   Text(0, 27, 'Page_Rank'),
#   Text(0, 28, 'Google_Index'),
#   Text(0, 29, 'Links_pointing_to_page'),
#   Text(0, 30, 'Statistical_report'),
#   Text(0, 31, 'Result')])

# %%
x=data.iloc[:,1:31].values
y=data.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.shape
# Out:
# (8798, 30)

# %%
y_train.shape
# Out:
# (8798,)

# %%
x_test.shape
# Out:
# (2200, 30)

# %%
y_test.shape
# Out:
# (2200,)
